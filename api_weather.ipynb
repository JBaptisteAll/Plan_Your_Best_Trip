# %%
import requests
import pandas as pd
import time

# API Key OpenWeatherMap
api_key = "YOUR_API_KEY_HERE"

# List of cities
villes = [
    "Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen", "Paris", "Amiens", "Lille", "Strasbourg",
    "Chateau du Haut Koenigsbourg", "Colmar", "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon",
    "Gorges du Verdon", "Bormes les Mimosas", "Cassis", "Marseille", "Aix en Provence", "Avignon", "Uzes", "Nimes",
    "Aigues Mortes", "Saintes Maries de la mer", "Collioure", "Carcassonne", "Ariege", "Toulouse", "Montauban",
    "Biarritz", "Bayonne", "La Rochelle"
]

# URL API Nominatim (OpenStreetMap - latitude et longitude)
nominatim_url = "https://nominatim.openstreetmap.org/search"

# List to store Lat & Long
meteo_resultats = []

# loop to get all results for each city
for ville in villes:
    params = {
        "city": ville,
        "country": "France",
        "format": "json",
        "limit": 1
    }

    headers = {
        "User-Agent": "NotNecessary"
    }

    # API request
    r = requests.get(nominatim_url, params=params, headers=headers)

    if r.status_code == 200:
        data = r.json()
        if data:
            lat = data[0]["lat"]
            lon = data[0]["lon"]

            # print of the result
            print(f"Coordinate of {ville}: Latitude = {lat}, Longitude = {lon}")

            
            # API request to get weather forecast from coordinate
            weather_url = f"https://api.openweathermap.org/data/2.5/forecast"
            weather_params = {
                "lat": lat,
                "lon": lon,
                "units": "metric",
                "appid": api_key                
            }


            # Weather API request
            weather_r = requests.get(weather_url, params=weather_params)

            if weather_r.status_code == 200:
                weather_data = weather_r.json()

                # Store the result into a DataFrame

                for day in weather_data['list']:
                    meteo_resultats.append({
                        "City": ville,
                        "Latitude": lat,
                        "Longitude": lon,
                        "Date": pd.to_datetime(day['dt'], unit='s').strftime('%Y-%m-%d'),
                        "Temp_Max": day['main']['temp_max'],
                        "Temp_Min": day['main']['temp_min'],
                        "Humidity": day['main']['humidity'],
                        "Weather": day['weather'][0]['description']
                    })
            else:
                print(f"Weather ERRROR for {ville}: {weather_r.status_code}")
                meteo_resultats.append({
                    "City": ville,
                    "Latitude": lat,
                    "Longitude": lon,
                    "Error_Meteo": "Requête météo échouée"
                })
            
            
            time.sleep(1)
        else:
            print(f"No Data found for {ville}")
            meteo_resultats.append({
                "City": ville,
                "Coordinate_Error": "No result found"
            })
    else:
        print(f"Coordinates Error for {ville}: {r.status_code}")
        meteo_resultats.append({
            "City": ville,
            "Coordinate_Error": "Request Failed"
        })

# Convert into a DataFrame
df_meteo = pd.DataFrame(meteo_resultats)
# Out:
# Coordinate of Mont Saint Michel: Latitude = 48.6359541, Longitude = -1.511459954959514
# Coordinate of St Malo: Latitude = 48.649518, Longitude = -2.0260409
# Coordinate of Bayeux: Latitude = 49.2764624, Longitude = -0.7024738
# Coordinate of Le Havre: Latitude = 49.4938975, Longitude = 0.1079732
# Coordinate of Rouen: Latitude = 49.4404591, Longitude = 1.0939658
# Coordinate of Paris: Latitude = 48.8534951, Longitude = 2.3483915
# Coordinate of Amiens: Latitude = 49.8941708, Longitude = 2.2956951
# Coordinate of Lille: Latitude = 50.6365654, Longitude = 3.0635282
# Coordinate of Strasbourg: Latitude = 48.584614, Longitude = 7.7507127
# Coordinate of Chateau du Haut Koenigsbourg: Latitude = 48.2495226, Longitude = 7.3454923
# Coordinate of Colmar: Latitude = 48.0777517, Longitude = 7.3579641
# Coordinate of Eguisheim: Latitude = 48.0447968, Longitude = 7.3079618
# Coordinate of Besancon: Latitude = 47.2380222, Longitude = 6.0243622
# Coordinate of Dijon: Latitude = 47.3215806, Longitude = 5.0414701
# Coordinate of Annecy: Latitude = 45.8992348, Longitude = 6.1288847
# Coordinate of Grenoble: Latitude = 45.1875602, Longitude = 5.7357819
# Coordinate of Lyon: Latitude = 45.7578137, Longitude = 4.8320114
# Coordinate of Gorges du Verdon: Latitude = 43.7496562, Longitude = 6.3285616
# Coordinate of Bormes les Mimosas: Latitude = 43.1506968, Longitude = 6.3419285
# Coordinate of Cassis: Latitude = 43.2140359, Longitude = 5.5396318
# Coordinate of Marseille: Latitude = 43.2961743, Longitude = 5.3699525
# Coordinate of Aix en Provence: Latitude = 43.5298424, Longitude = 5.4474738
# Coordinate of Avignon: Latitude = 43.9492493, Longitude = 4.8059012
# Coordinate of Uzes: Latitude = 44.0121279, Longitude = 4.4196718
# Coordinate of Nimes: Latitude = 43.8374249, Longitude = 4.3600687
# Coordinate of Aigues Mortes: Latitude = 43.5661521, Longitude = 4.19154
# Coordinate of Saintes Maries de la mer: Latitude = 43.4515922, Longitude = 4.4277202
# Coordinate of Collioure: Latitude = 42.52505, Longitude = 3.0831554
# Coordinate of Carcassonne: Latitude = 43.2130358, Longitude = 2.3491069
# Coordinate of Ariege: Latitude = 42.8458016, Longitude = 1.6067586
# Coordinate of Toulouse: Latitude = 43.6044622, Longitude = 1.4442469
# Coordinate of Montauban: Latitude = 44.0175835, Longitude = 1.3549991
# Coordinate of Biarritz: Latitude = 43.471143749999996, Longitude = -1.552726590666314
# Coordinate of Bayonne: Latitude = 43.4945144, Longitude = -1.4736657
# Coordinate of La Rochelle: Latitude = 46.159732, Longitude = -1.1515951

# %%
display(df_meteo)
# Out:
#                    City    Latitude           Longitude        Date  Temp_Max  \
# 0     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.08
# 1     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.29
# 2     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17      9.51
# 3     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.10
# 4     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.62
# ...                 ...         ...                 ...         ...       ...
# 1395        La Rochelle   46.159732          -1.1515951  2024-11-21     12.71
# 1396        La Rochelle   46.159732          -1.1515951  2024-11-21     12.28
# 1397        La Rochelle   46.159732          -1.1515951  2024-11-21     10.76
# 1398        La Rochelle   46.159732          -1.1515951  2024-11-21     13.70
# 1399        La Rochelle   46.159732          -1.1515951  2024-11-21      4.57
#
#       Temp_Min  Humidity           Weather
# 0         6.89        79         clear sky
# 1         8.85        75  scattered clouds
# 2         9.51        75     broken clouds
# 3        10.10        75   overcast clouds
# 4        10.62        74   overcast clouds
# ...        ...       ...               ...
# 1395     12.71        88     moderate rain
# 1396     12.28        76        light rain
# 1397     10.76        94        light rain
# 1398     13.70        91     moderate rain
# 1399      4.57        88        light rain
#
# [1400 rows x 8 columns]

# %%
df_meteo_paris = df_meteo[df_meteo["City"] == "Paris"]
display(df_meteo_paris)
# Out:
#       City    Latitude  Longitude        Date  Temp_Max  Temp_Min  Humidity  \
# 200  Paris  48.8534951  2.3483915  2024-11-16     10.48      9.35        70
# 201  Paris  48.8534951  2.3483915  2024-11-16      9.28      9.13        67
# 202  Paris  48.8534951  2.3483915  2024-11-16      8.45      8.00        70
# 203  Paris  48.8534951  2.3483915  2024-11-17      7.10      7.10        75
# 204  Paris  48.8534951  2.3483915  2024-11-17      7.98      7.98        73
# 205  Paris  48.8534951  2.3483915  2024-11-17      8.41      8.41        72
# 206  Paris  48.8534951  2.3483915  2024-11-17      8.52      8.52        78
# 207  Paris  48.8534951  2.3483915  2024-11-17     10.54     10.54        72
# 208  Paris  48.8534951  2.3483915  2024-11-17     10.99     10.99        60
# 209  Paris  48.8534951  2.3483915  2024-11-17      9.62      9.62        67
# 210  Paris  48.8534951  2.3483915  2024-11-17      8.74      8.74        71
# 211  Paris  48.8534951  2.3483915  2024-11-18      8.06      8.06        73
# 212  Paris  48.8534951  2.3483915  2024-11-18      7.57      7.57        77
# 213  Paris  48.8534951  2.3483915  2024-11-18      7.64      7.64        76
# 214  Paris  48.8534951  2.3483915  2024-11-18      8.79      8.79        76
# 215  Paris  48.8534951  2.3483915  2024-11-18      9.33      9.33        80
# 216  Paris  48.8534951  2.3483915  2024-11-18      9.89      9.89        82
# 217  Paris  48.8534951  2.3483915  2024-11-18     10.25     10.25        83
# 218  Paris  48.8534951  2.3483915  2024-11-18     10.64     10.64        86
# 219  Paris  48.8534951  2.3483915  2024-11-19     10.44     10.44        86
# 220  Paris  48.8534951  2.3483915  2024-11-19     10.52     10.52        85
# 221  Paris  48.8534951  2.3483915  2024-11-19     10.82     10.82        86
# 222  Paris  48.8534951  2.3483915  2024-11-19     12.08     12.08        81
# 223  Paris  48.8534951  2.3483915  2024-11-19     12.51     12.51        77
# 224  Paris  48.8534951  2.3483915  2024-11-19     11.36     11.36        82
# 225  Paris  48.8534951  2.3483915  2024-11-19      9.74      9.74        89
# 226  Paris  48.8534951  2.3483915  2024-11-19      6.49      6.49        84
# 227  Paris  48.8534951  2.3483915  2024-11-20      2.72      2.72        93
# 228  Paris  48.8534951  2.3483915  2024-11-20      3.91      3.91        94
# 229  Paris  48.8534951  2.3483915  2024-11-20      4.73      4.73        64
# 230  Paris  48.8534951  2.3483915  2024-11-20      4.25      4.25        84
# 231  Paris  48.8534951  2.3483915  2024-11-20      6.23      6.23        49
# 232  Paris  48.8534951  2.3483915  2024-11-20      6.23      6.23        50
# 233  Paris  48.8534951  2.3483915  2024-11-20      5.23      5.23        56
# 234  Paris  48.8534951  2.3483915  2024-11-20      4.80      4.80        60
# 235  Paris  48.8534951  2.3483915  2024-11-21      4.88      4.88        66
# 236  Paris  48.8534951  2.3483915  2024-11-21      4.74      4.74        65
# 237  Paris  48.8534951  2.3483915  2024-11-21      2.05      2.05        98
# 238  Paris  48.8534951  2.3483915  2024-11-21      2.25      2.25        99
# 239  Paris  48.8534951  2.3483915  2024-11-21      2.74      2.74        75
#
#               Weather
# 200     broken clouds
# 201     broken clouds
# 202  scattered clouds
# 203        few clouds
# 204     broken clouds
# 205   overcast clouds
# 206        light rain
# 207   overcast clouds
# 208   overcast clouds
# 209   overcast clouds
# 210   overcast clouds
# 211     broken clouds
# 212  scattered clouds
# 213     broken clouds
# 214   overcast clouds
# 215        light rain
# 216        light rain
# 217        light rain
# 218        light rain
# 219        light rain
# 220        light rain
# 221        light rain
# 222        light rain
# 223        light rain
# 224        light rain
# 225     moderate rain
# 226     moderate rain
# 227     moderate rain
# 228        light rain
# 229              snow
# 230        light rain
# 231        light rain
# 232         clear sky
# 233         clear sky
# 234     broken clouds
# 235        light rain
# 236        light rain
# 237              snow
# 238              snow
# 239   overcast clouds

# %%
df_meteo.head()
# Out:
#                 City    Latitude           Longitude        Date  Temp_Max  \
# 0  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.08
# 1  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.29
# 2  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17      9.51
# 3  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.10
# 4  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.62
#
#    Temp_Min  Humidity           Weather
# 0      6.89        79         clear sky
# 1      8.85        75  scattered clouds
# 2      9.51        75     broken clouds
# 3     10.10        75   overcast clouds
# 4     10.62        74   overcast clouds

# %%
df_meteo["Weather"].unique()
# Out:
# array(['clear sky', 'scattered clouds', 'broken clouds',
#        'overcast clouds', 'light rain', 'moderate rain', 'light snow',
#        'few clouds', 'snow', 'heavy intensity rain'], dtype=object)

# %%
# Dictionary for the quotation of weather condition, good condition get positive number
# and bad condition negative.
notations = {
    "clear sky": 600,
    "few clouds": 500,
    "scattered clouds": 400,
    "broken clouds": 300,
    "overcast clouds": 200,    

    "light intensity drizzle": -1,
    "drizzle": -2,
    "heavy intensity drizzle": -3,
    "light intensity drizzle rain": -4,
    "drizzle rain": -5,
    "heavy intensity drizzle rain": -6,
    "shower drizzle": -7,
    "shower rain and drizzle": -8,
    "heavy shower rain and drizzle": -9,    

    "light rain": -10,
    "moderate rain": -20,
    "heavy intensity rain": -30,
    "very heavy rain": -40,
    "extreme rain": -50,
    "freezing rain": -60,
    "light intensity shower rain": -70,
    "shower rain": -80,
    "heavy intensity shower rain": -90,
    "ragged shower rain": -100,

    "thunderstorm with light drizzle": -15,
    "thunderstorm with drizzle": -25,
    "thunderstorm with light rain": -35,
    "thunderstorm with rain": -45,
    "thunderstorm with heavy drizzle": -55,
    "thunderstorm with heavy rain": -65,
    "thunderstorm": -75,
    "heavy thunderstorm": -85,
    "ragged thunderstorm": -95,

    "light snow": -20,
    "snow": -40,
    "heavy snow": -60,
    "sleet": -80,
    "light shower sleet": -100,
    "shower sleet": -120,
    "light rain and snow": -140,
    "rain and snow": -160,
    "light shower snow": -180,
    "shower snow": -200,
    "heavy shower snow": -220,

    "mist": -10,
    "smoke": -20,
    "haze": -30,
    "sand/dust whirls": -40,
    "fog": -50,
    "sand": -60,
    "dust": -70,
    "volcanic ash": -90,
    "squalls": -100,
    "tornado": -400,
}

# %%
df_meteo["Weather_Score"] = df_meteo["Weather"].map(notations)

display(df_meteo)
# Out:
#                    City    Latitude           Longitude        Date  Temp_Max  \
# 0     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.08
# 1     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.29
# 2     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17      9.51
# 3     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.10
# 4     Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.62
# ...                 ...         ...                 ...         ...       ...
# 1395        La Rochelle   46.159732          -1.1515951  2024-11-21     12.71
# 1396        La Rochelle   46.159732          -1.1515951  2024-11-21     12.28
# 1397        La Rochelle   46.159732          -1.1515951  2024-11-21     10.76
# 1398        La Rochelle   46.159732          -1.1515951  2024-11-21     13.70
# 1399        La Rochelle   46.159732          -1.1515951  2024-11-21      4.57
#
#       Temp_Min  Humidity           Weather  Weather_Score
# 0         6.89        79         clear sky            600
# 1         8.85        75  scattered clouds            400
# 2         9.51        75     broken clouds            300
# 3        10.10        75   overcast clouds            200
# 4        10.62        74   overcast clouds            200
# ...        ...       ...               ...            ...
# 1395     12.71        88     moderate rain            -20
# 1396     12.28        76        light rain            -10
# 1397     10.76        94        light rain            -10
# 1398     13.70        91     moderate rain            -20
# 1399      4.57        88        light rain            -10
#
# [1400 rows x 9 columns]

# %%
# Total "Weather Score" points per city
total_points_par_ville = df_meteo.groupby("City")["Weather_Score"].sum().reset_index()
total_points_par_ville = total_points_par_ville.sort_values(by="Weather_Score", ascending=False)

display(total_points_par_ville)
# Out:
#                             City  Weather_Score
# 10            Bormes les Mimosas          12660
# 18              Gorges du Verdon          12430
# 12                        Cassis          11840
# 1                Aix en Provence          11640
# 24                     Marseille          11620
# 0                  Aigues Mortes          11350
# 33                      Toulouse          11250
# 14                     Collioure          11190
# 11                   Carcassonne          10960
# 27                         Nimes          10840
# 5                        Avignon          10650
# 34                          Uzes          10630
# 30      Saintes Maries de la mer          10430
# 4                         Ariege           9390
# 26                     Montauban           9330
# 23                          Lyon           8840
# 19                      Grenoble           7850
# 3                         Annecy           7280
# 20                   La Rochelle           6010
# 7                        Bayonne           5870
# 8                       Besancon           5840
# 16                         Dijon           5750
# 28                         Paris           5360
# 17                     Eguisheim           5360
# 15                        Colmar           5090
# 9                       Biarritz           5030
# 32                    Strasbourg           4530
# 13  Chateau du Haut Koenigsbourg           4370
# 29                         Rouen           3690
# 2                         Amiens           3620
# 25             Mont Saint Michel           3430
# 22                         Lille           3190
# 6                         Bayeux           2820
# 31                       St Malo           2190
# 21                      Le Havre           2000

# %%
df_meteo["Temp_Avg"] = (df_meteo["Temp_Max"] + df_meteo["Temp_Min"]) / 2
df_meteo.head()
# Out:
#                 City    Latitude           Longitude        Date  Temp_Max  \
# 0  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.08
# 1  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.29
# 2  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17      9.51
# 3  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.10
# 4  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.62
#
#    Temp_Min  Humidity           Weather  Weather_Score  Temp_Avg
# 0      6.89        79         clear sky            600     7.985
# 1      8.85        75  scattered clouds            400     9.070
# 2      9.51        75     broken clouds            300     9.510
# 3     10.10        75   overcast clouds            200    10.100
# 4     10.62        74   overcast clouds            200    10.620

# %%
import datetime

today_date = datetime.datetime.now().strftime("%Y-%m-%d")
name_file = f"weather_project_{today_date}.csv"

df_meteo.to_csv(name_file, index=True)

# %%
# Grouped by "City" and "Date" to get the weather score and the average temperature
df_grouped = df_meteo.groupby(['City', 'Date']).agg({
    'Weather_Score': 'sum',
    'Temp_Avg': 'mean'
}).unstack(level='Date')

# Display the AVG temp and Weather score side by side for each date
df_grouped = df_grouped.swaplevel(axis=1).sort_index(axis=1).round(2)

display(df_grouped)
# Out:
# Date                         2024-11-16               2024-11-17  \
#                                Temp_Avg Weather_Score   Temp_Avg
# City
# Aigues Mortes                     12.00           800      12.99
# Aix en Provence                   12.75           -20      12.79
# Amiens                             8.13           700       8.56
# Annecy                             6.80           900       7.20
# Ariege                            13.55           700      13.00
# Avignon                           11.61           400      11.35
# Bayeux                             9.81           500       9.59
# Bayonne                           15.00           500      13.25
# Besancon                           5.24           800       5.46
# Biarritz                          15.47           500      13.70
# Bormes les Mimosas                13.60           600      14.17
# Carcassonne                       11.00          1000      12.64
# Cassis                            14.89           -20      14.73
# Chateau du Haut Koenigsbourg       1.86           500       3.74
# Collioure                         13.89           500      14.95
# Colmar                             4.76           500       6.70
# Dijon                              5.24           400       6.05
# Eguisheim                          5.62           800       6.54
# Gorges du Verdon                   6.17          1100       6.90
# Grenoble                           8.56           900       9.24
# La Rochelle                       11.42          1000       9.62
# Le Havre                          11.15           190      11.68
# Lille                              9.36           400       8.72
# Lyon                               8.74           700       8.37
# Marseille                         15.42           -20      15.39
# Mont Saint Michel                  8.53          1000      10.46
# Montauban                         12.32          1000      10.69
# Nimes                             10.40           500      11.53
# Paris                              9.12          1000       8.99
# Rouen                              7.42           500       9.10
# Saintes Maries de la mer          13.64           -20      13.51
# St Malo                           10.64           400      11.57
# Strasbourg                         4.47           500       5.58
# Toulouse                          13.63          1600      12.19
# Uzes                               9.84           500      10.75
#
# Date                                       2024-11-18                \
#                              Weather_Score   Temp_Avg Weather_Score
# City
# Aigues Mortes                         3000      12.20          2800
# Aix en Provence                       2900      10.44          2400
# Amiens                                1180       9.20           330
# Annecy                                3200       5.76          2300
# Ariege                                2800      11.17          1800
# Avignon                               2600      10.76          2300
# Bayeux                                1180      10.42           330
# Bayonne                               1790      12.45          1600
# Besancon                              2000       7.15          1600
# Biarritz                              1370      12.74          1600
# Bormes les Mimosas                    3300      12.39          2500
# Carcassonne                           2800      10.96          2300
# Cassis                                2390      13.06          2500
# Chateau du Haut Koenigsbourg          1590       5.21          1180
# Collioure                             2700      14.12          2800
# Colmar                                1490       7.87          1600
# Dijon                                 2100       7.39          1600
# Eguisheim                             1490       7.56          1600
# Gorges du Verdon                      3100       6.06          1700
# Grenoble                              3700       7.39          1900
# La Rochelle                           2300      11.96          1490
# Le Havre                              1070      11.96           300
# Lille                                 1070       7.93           -90
# Lyon                                  3000       8.43          1600
# Marseille                             2490      13.56          2700
# Mont Saint Michel                     1490      10.68           760
# Montauban                             2500       8.74          2200
# Nimes                                 3100      10.26          2700
# Paris                                 1790       9.02          1160
# Rouen                                 1180       9.47           650
# Saintes Maries de la mer              2700      12.44          2700
# St Malo                                860      11.42           970
# Strasbourg                            1380       7.70          1600
# Toulouse                              2900      10.10          2500
# Uzes                                  2900       9.23          2600
#
# Date                         2024-11-19               2024-11-20  \
#                                Temp_Avg Weather_Score   Temp_Avg
# City
# Aigues Mortes                     13.03          2100      11.86
# Aix en Provence                   10.43          2500       9.54
# Amiens                             8.60          -110       3.86
# Annecy                             6.19           320       3.26
# Ariege                            11.15          2200       6.27
# Avignon                           10.35          1800       9.84
# Bayeux                             9.64          -110       5.49
# Bayonne                           13.81           650      11.17
# Besancon                           8.54           310       2.99
# Biarritz                          14.12           650      11.44
# Bormes les Mimosas                11.75          2800      10.80
# Carcassonne                       11.04          2000       9.33
# Cassis                            12.74          3000      11.68
# Chateau du Haut Koenigsbourg       6.41          -100       1.16
# Collioure                         14.07          2300      10.94
# Colmar                             9.04           100       4.14
# Dijon                              8.75           110       3.42
# Eguisheim                          8.69           310       3.81
# Gorges du Verdon                   4.77          2600       2.84
# Grenoble                           7.97           650       5.07
# La Rochelle                       14.09           -90       9.24
# Le Havre                          10.14          -100       6.63
# Lille                              8.48           320       4.04
# Lyon                               9.66          1180       6.62
# Marseille                         13.54          2900      12.59
# Mont Saint Michel                 10.72           -90       6.36
# Montauban                         10.84          1490       8.80
# Nimes                             10.33          1800      10.19
# Paris                             10.50          -100       4.76
# Rouen                              9.12          -110       4.25
# Saintes Maries de la mer          13.37          2100      12.50
# St Malo                           11.53          -100       8.01
# Strasbourg                         9.16           -90       4.56
# Toulouse                          11.58          1990       9.54
# Uzes                               9.71          1800       9.48
#
# Date                                       2024-11-21
#                              Weather_Score   Temp_Avg Weather_Score
# City
# Aigues Mortes                         1680       5.62           970
# Aix en Provence                       2080       3.58          1780
# Amiens                                 920       1.62           600
# Annecy                                -240      -1.94           800
# Ariege                                 490       7.66          1400
# Avignon                               2080       3.33          1470
# Bayeux                                1030       3.95          -110
# Bayonne                                760      11.59           570
# Besancon                               200       0.40           930
# Biarritz                               340      12.22           570
# Bormes les Mimosas                    1880       5.93          1580
# Carcassonne                           1770       7.19          1090
# Cassis                                2190       7.54          1780
# Chateau du Haut Koenigsbourg           160      -1.67          1040
# Collioure                             1390      10.14          1500
# Colmar                                 260       0.95          1140
# Dijon                                  760      -0.16           780
# Eguisheim                              240       0.72           920
# Gorges du Verdon                      2270      -1.57          1660
# Grenoble                                 0      -0.16           700
# La Rochelle                           1390      10.79           -80
# Le Havre                               620       4.52           -80
# Lille                                  720       2.95           770
# Lyon                                  1350       1.35          1010
# Marseille                             1670       8.40          1880
# Mont Saint Michel                      130       4.63           140
# Montauban                             1470       7.60           670
# Nimes                                 1670       3.41          1070
# Paris                                 1410       3.33           100
# Rouen                                  990       1.30           480
# Saintes Maries de la mer              1670       7.28          1280
# St Malo                                130       5.41           -70
# Strasbourg                              80       1.06          1060
# Toulouse                              1370       7.21           890
# Uzes                                  1770       2.29          1060

# %%
df_meteo.head()
# Out:
#                 City    Latitude           Longitude        Date  Temp_Max  \
# 0  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.08
# 1  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-16      9.29
# 2  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17      9.51
# 3  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.10
# 4  Mont Saint Michel  48.6359541  -1.511459954959514  2024-11-17     10.62
#
#    Temp_Min  Humidity           Weather  Weather_Score  Temp_Avg
# 0      6.89        79         clear sky            600     7.985
# 1      8.85        75  scattered clouds            400     9.070
# 2      9.51        75     broken clouds            300     9.510
# 3     10.10        75   overcast clouds            200    10.100
# 4     10.62        74   overcast clouds            200    10.620

# %%
import plotly.express as px

fig = px.scatter(df_meteo, x = "Weather_Score", y = "Temp_Avg")
fig.show()

# %%
df_meteo["Latitude"] = pd.to_numeric(df_meteo["Latitude"], errors="coerce")
df_meteo["Longitude"] = pd.to_numeric(df_meteo["Longitude"], errors="coerce")

df_meteo_pos = df_meteo[df_meteo["Weather_Score"] >= 0]

# %%
fig = px.density_mapbox(
    df_meteo_pos,
    lat="Latitude",
    lon="Longitude",
    z="Temp_Avg",
    mapbox_style="open-street-map",
    animation_frame="Date",
    zoom=3.5,
    radius=10,
    center={"lat": 46.603354, "lon": 1.888334}
)

fig.show()
